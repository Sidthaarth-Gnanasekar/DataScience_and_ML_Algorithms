# %%
import pandas as pd
df=pd.read_csv('HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  ...  Department  salary
# 0                    0.38             0.53  ...       sales     low
# 1                    0.80             0.86  ...       sales  medium
# 2                    0.11             0.88  ...       sales  medium
# 3                    0.72             0.87  ...       sales     low
# 4                    0.37             0.52  ...       sales     low
# ...                   ...              ...  ...         ...     ...
# 14994                0.40             0.57  ...     support     low
# 14995                0.37             0.48  ...     support     low
# 14996                0.37             0.53  ...     support     low
# 14997                0.11             0.96  ...     support     low
# 14998                0.37             0.52  ...     support     low
#
# [14999 rows x 10 columns]

# %%
df1=df.drop(['Department','salary'],axis='columns')
df1
# Out:
#        satisfaction_level  last_evaluation  ...  left  promotion_last_5years
# 0                    0.38             0.53  ...     1                      0
# 1                    0.80             0.86  ...     1                      0
# 2                    0.11             0.88  ...     1                      0
# 3                    0.72             0.87  ...     1                      0
# 4                    0.37             0.52  ...     1                      0
# ...                   ...              ...  ...   ...                    ...
# 14994                0.40             0.57  ...     1                      0
# 14995                0.37             0.48  ...     1                      0
# 14996                0.37             0.53  ...     1                      0
# 14997                0.11             0.96  ...     1                      0
# 14998                0.37             0.52  ...     1                      0
#
# [14999 rows x 8 columns]

# %%
df2 = df.corr(method='pearson')
df2
# Out:
#                        satisfaction_level  ...  promotion_last_5years
# satisfaction_level               1.000000  ...               0.025605
# last_evaluation                  0.105021  ...              -0.008684
# number_project                  -0.142970  ...              -0.006064
# average_montly_hours            -0.020048  ...              -0.003544
# time_spend_company              -0.100866  ...               0.067433
# Work_accident                    0.058697  ...               0.039245
# left                            -0.388375  ...              -0.061788
# promotion_last_5years            0.025605  ...               1.000000
#
# [8 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df2, cmap="coolwarm", annot=True)
plt.show()

# %%
df3=df2[['satisfaction_level','time_spend_company','Work_accident']]
df3.head()
# Out:
#                       satisfaction_level  time_spend_company  Work_accident
# satisfaction_level              1.000000           -0.100866       0.058697
# last_evaluation                 0.105021            0.131591      -0.007104
# number_project                 -0.142970            0.196786      -0.004741
# average_montly_hours           -0.020048            0.127755      -0.010143
# time_spend_company             -0.100866            1.000000       0.002120

# %%
dummy=pd.get_dummies(df['salary'],prefix='salary')
dummy
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
df5=pd.concat([df4,dummy],axis=1)
df5
# Out:
#        satisfaction_level  average_montly_hours  ...  salary_low  salary_medium
# 0                    0.38                   157  ...           1              0
# 1                    0.80                   262  ...           0              1
# 2                    0.11                   272  ...           0              1
# 3                    0.72                   223  ...           1              0
# 4                    0.37                   159  ...           1              0
# ...                   ...                   ...  ...         ...            ...
# 14994                0.40                   151  ...           1              0
# 14995                0.37                   160  ...           1              0
# 14996                0.37                   143  ...           1              0
# 14997                0.11                   280  ...           1              0
# 14998                0.37                   158  ...           1              0
#
# ...

# %%
df6=df5.drop(['salary_high'],axis='columns')
df6
# Out:
#        satisfaction_level  average_montly_hours  ...  salary_low  salary_medium
# 0                    0.38                   157  ...           1              0
# 1                    0.80                   262  ...           0              1
# 2                    0.11                   272  ...           0              1
# 3                    0.72                   223  ...           1              0
# 4                    0.37                   159  ...           1              0
# ...                   ...                   ...  ...         ...            ...
# 14994                0.40                   151  ...           1              0
# 14995                0.37                   160  ...           1              0
# 14996                0.37                   143  ...           1              0
# 14997                0.11                   280  ...           1              0
# 14998                0.37                   158  ...           1              0
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df6,df.left,train_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X_test,y_test)
# Out:
# 0.7803809523809524
